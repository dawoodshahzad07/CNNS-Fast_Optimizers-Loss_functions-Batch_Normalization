# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **1** Regression Loss
# <hr>

# %% [markdown]
# ## **Mean Squared Error(L2 loss)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# When we update weights we use MSE as a loss function and we minimize it by gradient descent.
# We don't use MSE if there are huge amount of outleirs in the data.

# %% [markdown]
# ## **Mean Absolute Error(L1 loss)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Non differetiable, use when there are huge amount of outliers.

# %% [markdown]
#   ## **Huber Loss**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# if the data has half percent of outliers use huber loss.

# %% [markdown]
# ## **2.** Classification Loss
# <hr>

# %% [markdown]
# ## **Binary Cross Enropy/log loss**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# if output is in binary form 0 or 1.

# %% [markdown]
# ## **Categorical Cross Entropy**

# %%
# More then binary output like 3 or 4, we use categorical cross entropy and it uses one hot encoding like 0 0 1, 0 1 0 etc.

# %% [markdown]
# ## **Sparse categorical cross-entropy**

# %%
# if output is more then 3 or 4 then we use it and it uses label encoding like 1,2,3,4....N.

# %% [markdown]
#  ## <h1>Optimizers
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# They helpp us get out of local minima.

# %% [markdown]
# ## **Improve the performance**
# <hr>

# %% [markdown]
# ## Hyperparameters

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Vanishing / Exploding Gradient

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Overfitting

# %%
#If we get training acuuracy > testing accuracy means model is overfitting.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Data

# %%
# if data is low then we can do transfer learning
